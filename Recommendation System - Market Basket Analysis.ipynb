# %%
import pandas as pd

import numpy as np

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

import os

# %%
os.chdir("G:\Recommendation Engine\Recommendation Systems")

# %%
retail = pd.read_excel("Online Retail.xlsx")

# %%
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  ...  UnitPrice CustomerID         Country
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER  ...       2.55    17850.0  United Kingdom
# 1    536365     71053                  WHITE METAL LANTERN  ...       3.39    17850.0  United Kingdom
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER  ...       2.75    17850.0  United Kingdom
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE  ...       3.39    17850.0  United Kingdom
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.  ...       3.39    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
retail['Description'] = retail['Description'].str.strip()
retail.dropna(axis=0, subset=['InvoiceNo'], inplace=True)

# %%
retail.head(3)
# Out:
#   InvoiceNo StockCode                         Description  ...  UnitPrice CustomerID         Country
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER  ...       2.55    17850.0  United Kingdom
# 1    536365     71053                 WHITE METAL LANTERN  ...       3.39    17850.0  United Kingdom
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER  ...       2.75    17850.0  United Kingdom
#
# [3 rows x 8 columns]

# %%
 retail[retail["InvoiceNo"].str.contains('C')].sample(3)
# Out:
#        InvoiceNo StockCode                         Description  ...  UnitPrice CustomerID         Country
# 211883   C555398     20703             BLUE PADDED SOFT MOBILE  ...       4.25    17375.0  United Kingdom
# 494829   C578276     21430  SET/3 RED GINGHAM ROSE STORAGE BOX  ...       3.39    17511.0  United Kingdom
# 288294   C562149     23205      CHARLOTTE BAG VINTAGE ALPHABET  ...       0.85    13534.0  United Kingdom
#
# [3 rows x 8 columns]

# %%
retail.InvoiceNo = retail.InvoiceNo.astype('str')

retail = retail[~retail["InvoiceNo"].str.contains('C')] ## Removing Credit transaction, invoice number has C

# %%
## To keep data small -> Filtering one country - France

basket= retail[retail.Country=="France"].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index("InvoiceNo")

# %%
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
#
# [5 rows x 1563 columns]

# %%
def encode_units(x):
    if x<=0:
        return 0
    if x>=1:
        return 1

# %%
baskets_sets = basket.applymap(encode_units)

# %%
# No need to track postage - It is not an item
baskets_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
baskets_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
# ...                             ...  ...                              ...
# 580986                            0  ...                                0
# 581001                            0  ...                                0
# 581171                            0  ...                                0
# 581279                            0  ...                                0
# 581587                            0  ...                                0
#
# [392 rows x 1562 columns]

# %%
## Support -> 0.07 implies atleast 7% transaction should have the combination of transaction
frequent_itemsets = apriori(baskets_sets, min_support=0.07, use_colnames=True)

# %%
frequent_itemsets.sort_values(by='support', ascending=False)
# Out:
#      support                                           itemsets
# 22  0.188776                               (RABBIT NIGHT LIGHT)
# 26  0.181122                    (RED TOADSTOOL LED NIGHT LIGHT)
# 21  0.170918                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 18  0.168367                    (PLASTERS IN TIN CIRCUS PARADE)
# 30  0.158163               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 11  0.153061                          (LUNCH BAG RED RETROSPOT)
# 14  0.142857                 (LUNCH BOX WITH CUTLERY RETROSPOT)
# 33  0.137755                      (SET/6 RED SPOTTY PAPER CUPS)
# 24  0.137755                         (RED RETROSPOT MINI CASES)
# 19  0.137755                         (PLASTERS IN TIN SPACEBOY)
# 32  0.132653               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 34  0.127551                    (SET/6 RED SPOTTY PAPER PLATES)
# 27  0.125000                         (REGENCY CAKESTAND 3 TIER)
# 36  0.125000                               (SPACEBOY LUNCH BOX)
# ...

# %% [markdown]
# #### Generate the rules with their corresponding support, confidence and lift:

# %%
### Rules is framed based on Lift Metric

rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#                                           antecedents  ... conviction
# 0                         (ALARM CLOCK BAKELIKE PINK)  ...   3.283859
# 1                        (ALARM CLOCK BAKELIKE GREEN)  ...   3.791383
# 2                          (ALARM CLOCK BAKELIKE RED)  ...   5.568878
# 3                        (ALARM CLOCK BAKELIKE GREEN)  ...   4.916181
# 4                         (ALARM CLOCK BAKELIKE PINK)  ...   3.293135
# 5                          (ALARM CLOCK BAKELIKE RED)  ...   4.153061
# 6                                (SPACEBOY LUNCH BOX)  ...   2.101190
# 7                              (DOLLY GIRL LUNCH BOX)  ...   3.102273
# 8                     (PLASTERS IN TIN CIRCUS PARADE)  ...   1.835747
# 9                          (PLASTERS IN TIN SPACEBOY)  ...   2.363588
# 10                    (PLASTERS IN TIN CIRCUS PARADE)  ...   2.104592
# 11                 (PLASTERS IN TIN WOODLAND ANIMALS)  ...   2.063681
# ...

# %% [markdown]
# - Intrepretation:  we can see that there are quite a few rules with a high lift value which means that it occurs more frequently than would be expected given the number of transaction and product combinations. We can also see several where the confidence is high as well. This part of the analysis is where the domain knowledge will come in handy.

# %%
rules.sort_values(by=['lift','confidence'], ascending=False )
# Out:
#                                           antecedents  ... conviction
# 2                          (ALARM CLOCK BAKELIKE RED)  ...   5.568878
# 3                        (ALARM CLOCK BAKELIKE GREEN)  ...   4.916181
# 5                          (ALARM CLOCK BAKELIKE RED)  ...   4.153061
# 4                         (ALARM CLOCK BAKELIKE PINK)  ...   3.293135
# 24                    (SET/6 RED SPOTTY PAPER PLATES)  ...   4.081633
# 21  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...  34.897959
# 1                        (ALARM CLOCK BAKELIKE GREEN)  ...   3.791383
# 0                         (ALARM CLOCK BAKELIKE PINK)  ...   3.283859
# 20  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...  34.489796
# 25                      (SET/6 RED SPOTTY PAPER CUPS)  ...   3.232653
# 18                    (SET/6 RED SPOTTY PAPER PLATES)  ...  21.556122
# 19                      (SET/6 RED SPOTTY PAPER CUPS)  ...   7.852041
# ...

# %%
## Filtering according to the need 
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
#                                           antecedents                           consequents  ...  leverage  conviction
# 2                          (ALARM CLOCK BAKELIKE RED)          (ALARM CLOCK BAKELIKE GREEN)  ...  0.069932    5.568878
# 3                        (ALARM CLOCK BAKELIKE GREEN)            (ALARM CLOCK BAKELIKE RED)  ...  0.069932    4.916181
# 17                    (SET/6 RED SPOTTY PAPER PLATES)  (SET/20 RED RETROSPOT PAPER NAPKINS)  ...  0.085121    4.336735
# 18                    (SET/6 RED SPOTTY PAPER PLATES)         (SET/6 RED SPOTTY PAPER CUPS)  ...  0.104878   21.556122
# 19                      (SET/6 RED SPOTTY PAPER CUPS)       (SET/6 RED SPOTTY PAPER PLATES)  ...  0.104878    7.852041
# 20  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...         (SET/6 RED SPOTTY PAPER CUPS)  ...  0.085433   34.489796
# 21  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...       (SET/6 RED SPOTTY PAPER PLATES)  ...  0.086474   34.897959
# ...

# %% [markdown]
# In looking at the rules, it seems that the green and red alarm clocks are purchased together and the red paper cups, napkins and plates are purchased together in a manner that is higher than the overall probability would suggest.
#
# At this point, you may want to look at how much opportunity there is to use the popularity of one product to drive sales of another. For instance, we can see that we sell 340 Green Alarm clocks but only 316 Red Alarm Clocks so maybe we can drive more Red Alarm Clock sales through recommendations?

# %% [markdown]
# ### These Patterns Change for different county Lets take Germany

# %%
basket2 = retail[retail.Country=='Germany'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
basket_set2 = basket2.applymap(encode_units)

# %%
freq_set = apriori(basket_set2,min_support=0.05,use_colnames=True)

# %%
rules2=association_rules(freq_set,metric="lift",min_threshold=1)
rules2
# Out:
#                                        antecedents  ... conviction
# 0                         (6 RIBBONS RUSTIC CHARM)  ...   1.707221
# 1                                        (POSTAGE)  ...   1.010651
# 2                    (CHARLOTTE BAG APPLES DESIGN)  ...   2.724289
# 3                                        (POSTAGE)  ...   1.009967
# 4                       (COFFEE MUG APPLES DESIGN)  ...   1.695113
# ..                                             ...  ...        ...
# 115              (WOODLAND CHARLOTTE BAG, POSTAGE)  ...   1.538882
# 116  (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)  ...   1.183260
# 117                       (WOODLAND CHARLOTTE BAG)  ...   1.449284
# 118           (ROUND SNACK BOXES SET OF4 WOODLAND)  ...   1.164835
# 119                                      (POSTAGE)  ...   1.009415
#
# [120 rows x 9 columns]

# %%
rules2[ (rules2['lift'] >= 4) &
        (rules2['confidence'] >= 0.5) ]
# Out:
#                                 antecedents                                  consequents  ...  leverage  conviction
# 22          (PLASTERS IN TIN CIRCUS PARADE)           (PLASTERS IN TIN WOODLAND ANIMALS)  ...  0.051846    2.076984
# 30               (PLASTERS IN TIN SPACEBOY)           (PLASTERS IN TIN WOODLAND ANIMALS)  ...  0.046488    2.011670
# 67            (RED RETROSPOT CHARLOTTE BAG)                     (WOODLAND CHARLOTTE BAG)  ...  0.050194    5.587746
# 87               (PLASTERS IN TIN SPACEBOY)  (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)  ...  0.042035    1.800419
# 98   (RED RETROSPOT CHARLOTTE BAG, POSTAGE)                     (WOODLAND CHARLOTTE BAG)  ...  0.046373    5.238512
# 100           (RED RETROSPOT CHARLOTTE BAG)            (WOODLAND CHARLOTTE BAG, POSTAGE)  ...  0.046584    4.041263
#
# [6 rows x 9 columns]
